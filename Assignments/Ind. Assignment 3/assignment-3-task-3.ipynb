# %% [markdown]
# # Instructions
#
# **Please follow these instructions carefully to ensure your submission is graded correctly:**
#
# - Fill in **your answers** in any place that says "YOUR CODE HERE" or "YOUR ANSWER HERE" in the provided `.ipynb` files.
#
# - Your answers to code-based questions must be **generated from code**. Hardcoded answers will result in a deduction of points.
#
# - Do not change the **autograding cells** labelled with `"AUTOGRADING CELL - DO NOT TOUCH!"`. Modifying or deleting them may lead to incorrect grading results.
#
# - All plots must have appropriate **axis labels** including units where applicable. Failing to do so will result in a partial deduction of points.
#
# - Always proide **units** for quantities where applicable. Failing to do so will result in a partial deduction of points.
#
# - The **code quality** will not be graded. However, concise, well-structured code makes it easier to awared partial points in case of errors.
#
# - The quality of **written answers** and **figures** will be considered during grading.
#
# - Do not use additional packages that are not part of the course **environment**. This would lead to errors during autograding.
#
# - Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# - Submissions must be your own work, **plagiarism** from the web or peers will be checked for and sanctioned.
#
# - Please upload only the provided `.ipynb` files, filled in with your answers.
#
# - Please **do not** put the `.ipynb` files into archives (e.g., `.zip`, `.tar.gz`); also `.py` files will **not** be accepted. Please **do not change the file names** and do not upload additional files.
#
# - Submission on ISIS *(for TU Berlin students)* requires **two-factor authentication**.

# %% [markdown]
# ---

# %% [markdown]
# ## Task 3: Optimisation for Modelling Electricity Markets (36 points)
#
# Build a simple electricity market model for minimising operational costs within technical constraints for three regions in one particular hour considering the following information:
#
# The operational fleet of power plants in the three regions is specified as follows:
#
# | Name | Technology     | Region     | Marginal Cost [€/MWh] | Capacity [MW] |
# | ----- | -------------- | ---------- | --------------------- | ------------- |
# | Coal A | Coal           | A | 35                    | 8000         |
# | RES A| RES | A | 1                     |  1000         |
# | Gas A | Gas            | A | 80                    | 4000         |
# | Hydro B | Hydro          | B | 2                     | 4000          |
# | Gas B | Gas            | B | 70                    | 2000          |
# | RES C | RES            | C | 0                     | 3000          |
#
# The electricity demand in the regions reads as follows:
#
# | Region    | Demand [MW] |
# | ---------- | ----------- |
# | A | 10000       |
# | B | 4000        |
# | C | 1000         |
#
# The transmission capacities read as follows:
#
# | Start      | End        | Capacity [MW] |
# | ---------- | ---------- | ------------- |
# | A | B | 2000           |
# | B | C | 300            |
# | A | C | 4000           |
#
# Assume equal non-zero reactances for the transmission lines.
#
# **Note: None of the answers can be hard-coded numbers. All answers must be derived from the model results.**

# %%
import linopy
import pypsa
import numpy as np
import pandas as pd

# %%
# marginal costs in EUR/MWh
marginal_costs = pd.DataFrame({
    "A": {"Coal": 35, "RES": 1, "Gas": 80},
    "B": {"Gas": 70, "Hydro": 2},
    "C": {"RES": 0},
})
marginal_costs.columns.name = "region"
marginal_costs.index.name = "technology"

# power plant capacities (nominal powers in MW) in each country
capacities = pd.DataFrame({
    "A": {"Coal": 8000, "RES": 1000, "Gas": 4000},
    "B": {"Gas": 2000, "Hydro": 4000},
    "C": {"RES": 3000},
})
capacities.columns.name = "region"
capacities.index.name = "technology"

# transmission capacities in MW
transmission = pd.Series({"A-B": 2000, "A-C": 4000, "B-C": 300})
transmission.index.name = "transmission"

# country electrical loads in MW
loads = pd.Series({"A": 10000, "B": 4000, "C": 1000}, name="region")

# %% [markdown]
# **a)** Build and solve the optimisation model using `linopy` by following the steps outlined below.
#
# **a.1)** Create a `linopy.Model` instance under the name `m`. **(1 point)**
#
# **a.2)** Create all variables for generation (`m.g`) and transmission (`m.f`). **(2 points)**
#
# **a.3)** Create the objective function to minimise total operational costs. **(2 points)**
#
# **a.4)** Build the necessary constraints for generation limits, transmission limits and the Kirchhoff laws. **(6 points)**
#
# **a.5)** Solve the model with HiGHS. **(1 point)**

# %%
# YOUR CODE HERE

# %% [markdown]
# **a.6)** Return the total operational cost as a `float`. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, float)

# %% [markdown]
# **a.7)** Return the optimal generator dispatch as a `pandas.DataFrame` where the index represents the technology of the generator (e.g. `Coal`), the columns represent the region (e.g. `A`), and the values represent the optimal dispatch in MW. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.DataFrame)
assert _.columns.symmetric_difference(["A", "B", "C"]).empty
assert _.index.symmetric_difference(["Coal", "Gas", "Hydro", "RES"]).empty

# %% [markdown]
# **a.8)** Return the optimal power flows as a `pandas.Series` where the index represents the name of the transmission line (e.g. `A-B`) and the values represent the optimal power flow in MW. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(transmission.index).empty

# %% [markdown]
# **a.9)** Return the locational marginal prices (LMPs) as a `pandas.Series` where the index represents the name of the region (e.g. `A`) and the values represent the LMPs in €/MWh. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(loads.index).empty

# %% [markdown]
# **b)** Build and solve the optimisation model using `pypsa` by following the steps outlined below.
#
# **b.1)** Create a `pypsa.Network` instance under the name `n`. **(1 point)**
#
# **b.2)** Add the generators, lines, and loads to the network. **(5 points)**
#
# **b.3)** Solve the network with HiGHS. **(1 point)**

# %%
# YOUR CODE HERE

# %% [markdown]
# **b.4)** Return the total operational cost as a `float`. *(Hint: It should be the same as in the previous task.)* **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, float)

# %% [markdown]
# **b.5)** Return the optimal generator dispatch as a `pandas.Series` where the index represents the name of the generator (e.g. `Coal A`) and the values represent the optimal dispatch in MW. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
expected_index = [
    tech + " " + region
    for (tech, region) in capacities.stack().index
]
assert _.index.symmetric_difference(expected_index).empty

# %% [markdown]
# **b.6)** Return the optimal power flows as a `pandas.Series` where the index represents the name of the transmission line (e.g. `A-B`) and the values represent the optimal power flow in MW. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(transmission.index).empty

# %% [markdown]
# **b.7)** Return the locational marginal prices (LMPs) as a `pandas.Series` where the index represents the name of the region (e.g. `A`) and the values represent the LMPs in €/MWh. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(loads.index).empty

# %% [markdown]
# **c)** Now remove the line between region B and C from the `pypsa` network and re-solve the optimisation problem. **(2 points)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!

# %% [markdown]
# **c.1)** Return the absolute difference in total operational cost (in €) compared to the solution in **b)** as a `float`. Positive values indicate an increase in cost; negative values indicate a decreased costs. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, float)

# %% [markdown]
# **c.2)** Return the optimal power flows as a `pandas.Series` where the index represents the name of the transmission line (e.g. `A-B`) and the values represent the optimal power flow in MW. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(["A-B", "A-C"]).empty

# %% [markdown]
# **c.3)** Return the locational marginal prices (LMPs) as a `pandas.Series` where the index represents the name of the region (e.g. `A`) and the values represent the LMPs in €/MWh. **(1 point)**

# %%
# YOUR CODE HERE

# %%
### AUTOGRADING CELL - DO NOT TOUCH!
assert isinstance(_, pd.Series)
assert _.index.symmetric_difference(loads.index).empty

# %% [markdown]
# **c.4)** What is the main reason for the change in operational costs? Describe in 1-2 sentences. **(4 points)**

# %% [markdown]
# YOUR ANSWER HERE
